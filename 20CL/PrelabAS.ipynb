# %% [markdown]
# ### Question 1: Photon Energies for Shortest and Longest Visible Wavelengths
#
# I used the information from the Overview and Equation 1 to find the photon energies corresponding to the shortest and longest wavelengths visible by the cone cells in the typical human eye. The document states that the human eye, under photopic vision, responds to wavelengths between $430 \, \mathrm{nm}$ and $680 \, \mathrm{nm}$, where efficiency drops to about 1% at these limits. Equation 1, $E_\gamma = \frac{1240}{\lambda(\mathrm{nm})} \, \mathrm{eV}$, provides the energy of a photon in electron-volts (eV) given its wavelength in nanometers (nm), using the conversion constant $\hbar c = 197.3 \, \mathrm{eV} \cdot \mathrm{nm}$ scaled appropriately. First, I calculated the energy for the shortest visible wavelength, $\lambda = 430 \, \mathrm{nm}$: $E_\gamma = \frac{1240}{430} \approx 2.88 \, \mathrm{eV}$. Next, I computed the energy for the longest visible wavelength, $\lambda = 680 \, \mathrm{nm}$: $E_\gamma = \frac{1240}{680} \approx 1.82 \, \mathrm{eV}$. These calculations confirm that the photon energies range from approximately 1.82 eV to 2.88 eV across the visible spectrum detectable by cone cells. I noted that very bright sources just outside this range might be faintly visible, but for this lab, I’ll focus on the specified 430–680 nm range, which aligns with the Spencer spectrometer’s capabilities.

# %% [markdown]
# ### Question 2: Photon Energies and Wavelengths for $H_\alpha$, $H_\beta$, and $H_\gamma$
#
# I started with Equation 7, $E_\gamma = 13.6 \, \mathrm{eV} \left( \frac{1}{n_f^2} - \frac{1}{n_i^2} \right)$, to compute the photon energies for the hydrogen emission lines $H_\alpha$, $H_\beta$, and $H_\gamma$, where the Balmer series has $n_f = 2$, and the initial states are $n_i = 3, 4, 5$ respectively. For $H_\alpha$ ($n_i = 3$, $n_f = 2$): $E_\gamma = 13.6 \left( \frac{1}{2^2} - \frac{1}{3^2} \right) = 13.6 \left( \frac{1}{4} - \frac{1}{9} \right) = 13.6 \left( 0.25 - 0.111 \right) = 13.6 \times 0.139 \approx 1.89 \, \mathrm{eV}$. For $H_\beta$ ($n_i = 4$, $n_f = 2$): $E_\gamma = 13.6 \left( \frac{1}{4} - \frac{1}{16} \right) = 13.6 \left( 0.25 - 0.0625 \right) = 13.6 \times 0.1875 \approx 2.55 \, \mathrm{eV}$. For $H_\gamma$ ($n_i = 5$, $n_f = 2$): $E_\gamma = 13.6 \left( \frac{1}{4} - \frac{1}{25} \right) = 13.6 \left( 0.25 - 0.04 \right) = 13.6 \times 0.21 \approx 2.86 \, \mathrm{eV}$. Next, I used Equation 1, $E_\gamma = \frac{1240}{\lambda(\mathrm{nm})} \, \mathrm{eV}$, to find the wavelengths. For $H_\alpha$: $\lambda = \frac{1240}{1.89} \approx 656 \, \mathrm{nm}$. For $H_\beta$: $\lambda = \frac{1240}{2.55} \approx 486 \, \mathrm{nm}$. For $H_\gamma$: $\lambda = \frac{1240}{2.86} \approx 434 \, \mathrm{nm}$. These wavelengths fall within the 430–680 nm visible range, confirming they are observable with the Spencer spectrometer. I double-checked my calculations to ensure accuracy, noting that these values align with the Balmer series expectations, and I’m excited to measure them in the lab.

# %% [markdown]
# ### Question 3: Transitions Contributing to $H_\alpha$, $H_\beta$, and $H_\gamma$
#
# I examined Figure 2 (the hydrogen term diagram) to identify the transitions contributing to the visible Balmer series lines $H_\alpha$, $H_\beta$, and $H_\gamma$, where $n_f = 2$. The document highlights one transition for $H_\alpha$ shown in red, which is $3p$ to $2s$, and I need to draw the other two contributing transitions for $H_\alpha$ and list all transitions for the three lines. For $H_\alpha$ ($n_i = 3$ to $n_f = 2$), the allowed transitions follow the $\Delta \ell = 1$ selection rule. This rule, the $\Delta \ell = \pm 1$ selection rule, governs electric dipole transitions by ensuring angular momentum conservation. This rule allows transitions where the orbital angular momentum $\ell$ changes by $\pm 1$ (e.g., $p \to s$ or $d \to p$), but forbids changes like $s \to s$ or $d \to d$. I am reading Griffith's right now, and in the angular momentum part it taught me this rule.
#
# Besides $3p$ to $2s$, I identified $3d$ to $2p$ (since $\ell = 2$ to $\ell = 1$) and $3s$ to $2p$ (since $\ell = 0$ to $\ell = 1$), which I’ll draw as diagonal lines on the figure. For $H_\beta$ ($n_i = 4$ to $n_f = 2$), the transitions are $4p$ to $2s$, $4d$ to $2p$, and $4f$ to $2p$ (since $\ell = 0, 1, 2$ to $\ell = 1$ or 0 with $\Delta \ell = 1$). For $H_\gamma$ ($n_i = 5$ to $n_f = 2$), the transitions are $5p$ to $2s$, $5d$ to $2p$, $5f$ to $2p$, and $5g$ to $2p$ (since $\ell = 0$ to 3 to $\ell = 1$ or 0 with $\Delta \ell = 1$). The total number of transitions is the sum: 3 for $H_\alpha$, 3 for $H_\beta$, and 4 for $H_\gamma$, totaling 10 transitions. My list of transitions in usual notation is: $3p \to 2s$, $3d \to 2p$, $3s \to 2p$ (for $H_\alpha$); $4p \to 2s$, $4d \to 2p$, $4f \to 2p$ (for $H_\beta$); $5p \to 2s$, $5d \to 2p$, $5f \to 2p$, $5g \to 2p$ (for $H_\gamma$). I’ll turn in the annotated figure with these transitions marked, ensuring the $\Delta \ell = 1$ rule is followed, which excites me as I prepare to see these lines in the lab.

# %% [markdown]
# ### Question 4: Helium Balmer-Like Transitions and Wavelengths
#
# I used Figure 3 (helium term diagram) and the blue energy level numbers to evaluate photon energies for transitions analogous to the hydrogen Balmer series, with $n_f = 2$ (excited electron in $1s2$ states) and $n_i = 3, 4, 5$ (excited electron in $1s3$, $1s4$, $1s5$ states).
#
# For singlet states, I noted energies: $1s2s$ at 20.61 eV, $1s2p$ at 20.96 eV, $1s3s$ at 22.92 eV, $1s3p$ at 23.01 eV, $1s3d$ at 23.07 eV, $1s4s$ at 23.73 eV, $1s4p$ at 23.74 eV, $1s4d$ at 23.74 eV, $1s5s$ at 23.98 eV, $1s5p$ at 23.98 eV, $1s5d$ at 23.99 eV (ground state at -24.59 eV). For triplet states: $1s2s$ at 19.82 eV, $1s2p$ at 20.96 eV, $1s3s$ at 22.72 eV, $1s3p$ at 22.92 eV, $1s3d$ at 23.07 eV, $1s4s$ at 23.69 eV, $1s4p$ at 23.70 eV, $1s4d$ at 23.71 eV, $1s5s$ at 23.97 eV, $1s5p$ at 23.97 eV, $1s5d$ at 23.98 eV.
#
# Applying $\Delta \ell = \pm 1$, the allowed singlet transitions ($1snp \to 1s2s$, $1snd \to 1s2p$ for $n = 3, 4, 5$) are: $1s3p \to 1s2s$ ($23.01 - 20.61 = 2.40 , \mathrm{eV}$, $\lambda = \frac{1240}{2.40} \approx 517 , \mathrm{nm}$), $1s3d \to 1s2p$ ($23.07 - 20.96 = 2.11 , \mathrm{eV}$, $\lambda = \frac{1240}{2.11} \approx 588 , \mathrm{nm}$), $1s4p \to 1s2s$ ($23.74 - 20.61 = 3.13 , \mathrm{eV}$, $\lambda = \frac{1240}{3.13} \approx 396 , \mathrm{nm}$), $1s4d \to 1s2p$ ($23.74 - 20.96 = 2.78 , \mathrm{eV}$, $\lambda = \frac{1240}{2.78} \approx 446 , \mathrm{nm}$), $1s5p \to 1s2s$ ($23.98 - 20.61 = 3.37 , \mathrm{eV}$, $\lambda = \frac{1240}{3.37} \approx 368 , \mathrm{nm}$), $1s5d \to 1s2p$ ($23.99 - 20.96 = 3.03 , \mathrm{eV}$, $\lambda = \frac{1240}{3.03} \approx 409 , \mathrm{nm}$).
#
# Allowed triplet transitions: $1s3p \to 1s2s$ ($22.92 - 19.82 = 3.10 , \mathrm{eV}$, $\lambda = \frac{1240}{3.10} \approx 400 , \mathrm{nm}$), $1s3d \to 1s2p$ ($23.07 - 20.96 = 2.11 , \mathrm{eV}$, $\lambda = 588 , \mathrm{nm}$), $1s4p \to 1s2s$ ($23.70 - 19.82 = 3.88 , \mathrm{eV}$, $\lambda = \frac{1240}{3.88} \approx 320 , \mathrm{nm}$), $1s4d \to 1s2p$ ($23.71 - 20.96 = 2.75 , \mathrm{eV}$, $\lambda = \frac{1240}{2.75} \approx 451 , \mathrm{nm}$), $1s5p \to 1s2s$ ($23.97 - 19.82 = 4.15 , \mathrm{eV}$, $\lambda = \frac{1240}{4.15} \approx 299 , \mathrm{nm}$), $1s5d \to 1s2p$ ($23.98 - 20.96 = 3.02 , \mathrm{eV}$, $\lambda = \frac{1240}{3.02} \approx 411 , \mathrm{nm}$).
#
# Visible lines (430–680 nm) are: singlet $517 , \mathrm{nm}$, $588 , \mathrm{nm$, $446 , \mathrm{nm}$; triplet $588 , \mathrm{nm}$, $451 , \mathrm{nm}$. Total: 5 visible transitions. I created tables using the Python code below and drew the transitions on Fig. 3 using blue for singlet and green for triplet, excited to measure these spectral lines in the lab.
#
# Here’s the Python code I used to generate the tables:

# %%
import pandas as pd

# Data for singlet and triplet transitions with Δℓ = +-1
data = {
    "State": ["Singlet", "Singlet", "Singlet", "Singlet", "Singlet", "Singlet",
              "Triplet", "Triplet", "Triplet", "Triplet", "Triplet", "Triplet"],
    "Transition": ["1s3p → 1s2s", "1s3d → 1s2p", "1s4p → 1s2s", "1s4d → 1s2p", "1s5p → 1s2s", "1s5d → 1s2p",
                   "1s3p → 1s2s", "1s3d → 1s2p", "1s4p → 1s2s", "1s4d → 1s2p", "1s5p → 1s2s", "1s5d → 1s2p"],
    "Initial Energy (eV)": [23.01, 23.07, 23.74, 23.74, 23.98, 23.99,
                           22.92, 23.07, 23.70, 23.71, 23.97, 23.98],
    "Final Energy (eV)": [20.61, 20.96, 20.61, 20.96, 20.61, 20.96,
                         19.82, 20.96, 19.82, 20.96, 19.82, 20.96],
    "Photon Energy (eV)": [2.40, 2.11, 3.13, 2.78, 3.37, 3.03,
                          3.10, 2.11, 3.88, 2.75, 4.15, 3.02],
    "Wavelength (nm)": [517, 588, 396, 446, 368, 409,
                       400, 588, 320, 451, 299, 411],
    "Visible (430–680 nm)": ["Yes", "Yes", "No", "Yes", "No", "No",
                            "No", "Yes", "No", "Yes", "No", "No"]
}

# Create DataFrame
df = pd.DataFrame(data)

# Display the table
print(df.to_string(index=False))

# Save to CSV for Excel compatibility
df.to_csv("Helium_Transitions_DeltaL.csv", index=False)
# Out:
#   State  Transition  Initial Energy (eV)  Final Energy (eV)  Photon Energy (eV)  Wavelength (nm) Visible (430–680 nm)
# Singlet 1s3p → 1s2s                23.01              20.61                2.40              517                  Yes
# Singlet 1s3d → 1s2p                23.07              20.96                2.11              588                  Yes
# Singlet 1s4p → 1s2s                23.74              20.61                3.13              396                   No
# Singlet 1s4d → 1s2p                23.74              20.96                2.78              446                  Yes
# Singlet 1s5p → 1s2s                23.98              20.61                3.37              368                   No
# Singlet 1s5d → 1s2p                23.99              20.96                3.03              409                   No
# Triplet 1s3p → 1s2s                22.92              19.82                3.10              400                   No
# ...
